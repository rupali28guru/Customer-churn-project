# %% [markdown]
# # Customer churn project

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
df = pd.read_csv("C:/Users/ACER/Downloads/customer_churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
11/7043 *100 # <- Percentage missing values from "TotalCharges" column
# Out:
# 0.1561834445548772

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Checking for outliers

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
sns.boxplot(df['tenure'])
# Out:
# <Axes: >

# %%
for col in df.columns: #to get all coloumn name from this 
     if df[col].dtype!='object':
        sns.boxplot(df[col])
        plt.xlabel(col)
        plt.show()

# %%
# statical method <- IQR, LL, UL

# domain specific <- Indepth knowledge of data

# %% [markdown]
# # Data Encoding

# %%
#Label encoding (ordinal data encoding like 0,1,2,3 this all are label)

#onehot encoding

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col]=le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   int32
#  1   gender            7032 non-null   int32
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   int32
#  4   Dependents        7032 non-null   int32
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   int32
#  7   MultipleLines     7032 non-null   int32
#  8   InternetService   7032 non-null   int32
#  9   OnlineSecurity    7032 non-null   int32
#  10  OnlineBackup      7032 non-null   int32
#  11  DeviceProtection  7032 non-null   int32
#  12  TechSupport       7032 non-null   int32
#  13  StreamingTV       7032 non-null   int32
#  14  StreamingMovies   7032 non-null   int32
#  15  Contract          7032 non-null   int32
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5365       0              0        1           0       1
# 1        3953       1              0        0           0      34
# 2        2558       1              0        0           0       2
# 3        5524       1              0        0           0      45
# 4        6500       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.drop('CustomerID, axis=1, inplace=True')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df.drop('CustomerID, axis=1, inplace=True')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %% [markdown]
# # Correlation

# %%
#Simple correlation -> correlation matrix

# Multiple Correlation -> VIF

# %%
df.corr()
# Out:
#                   customerID    gender  SeniorCitizen   Partner  Dependents  \
# customerID          1.000000  0.006235      -0.002368 -0.026509   -0.011871
# gender              0.006235  1.000000      -0.001819 -0.001379    0.010349
# SeniorCitizen      -0.002368 -0.001819       1.000000  0.016957   -0.210550
# Partner            -0.026509 -0.001379       0.016957  1.000000    0.452269
# Dependents         -0.011871  0.010349      -0.210550  0.452269    1.000000
# tenure              0.007209  0.005285       0.015683  0.381912    0.163386
# PhoneService       -0.006987 -0.007515       0.008392  0.018397   -0.001078
# MultipleLines       0.004497 -0.006908       0.146287  0.142717   -0.024975
# InternetService    -0.012335 -0.002236      -0.032160  0.000513    0.044030
# OnlineSecurity      0.013740 -0.014899      -0.127937  0.150610    0.151198
# OnlineBackup       -0.002960 -0.011920      -0.013355  0.153045    0.090231
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
df.drop('TotalCharges',axis=1, inplace=True)

# %%
df.drop('tenure' axis=1, inplace=True)

# %% [markdown]
# # Multi correlation

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X= df.drop('Churn', axis=1)

# %%
X
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5365       0              0        1           0       1
# 1           3953       1              0        0           0      34
# 2           2558       1              0        0           0       2
# 3           5524       1              0        0           0      45
# 4           6500       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4843       1              0        1           1      24
# 7039        1524       0              0        1           1      72
# 7040        3358       0              0        1           1      11
# 7041        5923       1              1        1           0       4
# 7042        2221       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0                0              1                0               0
# ...

# %%
y =df['Churn']

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int32

# %%
vif_data=pd.DataFrame()
vif_data['Columns'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#              Columns        VIF
# 0         customerID   3.332163
# 1             gender   1.906927
# 2      SeniorCitizen   1.342235
# 3            Partner   2.803574
# 4         Dependents   1.952375
# 5             tenure  14.157528
# 6      MultipleLines   2.524900
# 7    InternetService   2.697464
# 8     OnlineSecurity   2.233678
# 9       OnlineBackup   2.456387
# 10  DeviceProtection   2.621383
# 11       TechSupport   2.368310
# 12       StreamingTV   3.100413
# 13   StreamingMovies   3.120797
# 14          Contract   4.064531
# 15  PaperlessBilling   2.497738
# 16     PaymentMethod   2.827439
# 17      TotalCharges   9.803947

# %%
X.drop('MonthlyCharges', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 X.drop('MonthlyCharges', axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
vif_data=pd.DataFrame()
vif_data['Columns'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#              Columns        VIF
# 0         customerID   3.332163
# 1             gender   1.906927
# 2      SeniorCitizen   1.342235
# 3            Partner   2.803574
# 4         Dependents   1.952375
# 5             tenure  14.157528
# 6      MultipleLines   2.524900
# 7    InternetService   2.697464
# 8     OnlineSecurity   2.233678
# 9       OnlineBackup   2.456387
# 10  DeviceProtection   2.621383
# 11       TechSupport   2.368310
# 12       StreamingTV   3.100413
# 13   StreamingMovies   3.120797
# 14          Contract   4.064531
# 15  PaperlessBilling   2.497738
# 16     PaymentMethod   2.827439
# 17      TotalCharges   9.803947

# %%
X #idependent data and y is dependent data
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5365       0              0        1           0       1
# 1           3953       1              0        0           0      34
# 2           2558       1              0        0           0       2
# 3           5524       1              0        0           0      45
# 4           6500       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4843       1              0        1           1      24
# 7039        1524       0              0        1           1      72
# 7040        3358       0              0        1           1      11
# 7041        5923       1              1        1           0       4
# 7042        2221       1              0        0           0      66
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0                 1                0               0             2
# ...

# %%
plt.figure(figsize=(15, 12))

sns.heatmap(X.corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75, random_state=100)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lo_model = LogisticRegression()

# %%
lo_model.fit(X_train, y_train)
# Out:
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lo_predict = lo_model.predict(X_test)

# %%
lo_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, lo_predict)
# Out:
# 0.7878270762229806

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier( )

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_predict = dt_model.predict(X_test)

# %%
accuracy_score(y_test, dt_predict)
# Out:
# 0.7258248009101251

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_predict = rf_model.predict(X_test)

# %%
accuracy_score(y_test,rf_predict)
# Out:
# 0.7878270762229806
